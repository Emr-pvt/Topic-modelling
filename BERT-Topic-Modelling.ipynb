# %% [markdown]
# # Topic Modelling
# Détection de thématiques (topic modeling) : extraire les thématiques pertinentes traitées par les abstracts.

# %%
# !pip install bertopic[visualization] --quiet

# %%
# !pip install numpy==1.19.5

# %% [markdown]
# # **Imports**

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from bertopic import BERTopic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_json('/content/gdrive/MyDrive/Exam/AgrSmall_cleaned.json')
df.head()
# Out:
#        doi  ... sources
# 0  10.3390  ...    mdpi
# 1  10.3390  ...    mdpi
# 2  10.3390  ...    mdpi
# 3  10.3390  ...    mdpi
# 4  10.3390  ...    mdpi
#
# [5 rows x 6 columns]

# %% [markdown]
# Fortunately this kind of methods don't need much pre-processing. That way we will just have to pass our data to model topics.

# %% [markdown]
# # **Load data**

# %% [markdown]
# We need to have some idea of how many topics we need to extract from our abstracts. Fortunately, there is a column called Keywords which can be interpreted as a column of topics. We see that there are 33 topics in our abstracts.

# %%
len(df['keywords'].value_counts())
# Out:
# 33

# %%
docs = list(df.loc[:, "abstracts"].values)

# %% [markdown]
# # **Creating Topics**

# %%
model = BERTopic(language="english",nr_topics="auto")

# %%
topics, probs = model.fit_transform(docs)

# %% [markdown]
# # We can then extract most frequent topics:

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1   1478
# 1       0    223
# 2       1    221
# 3       2    193
# 4       3    165
# ..    ...    ...
# 56     55     12
# 57     56     12
# 58     57     11
# 59     58     11
# 60     59     10
#
# [61 rows x 2 columns]

# %% [markdown]
# Subject -1 means outliers. It is not relevant for our application as we are trying to group those that can be grouped and not the outliers.

# %% [markdown]
# # Get Individual Topics

# %%
model.get_topic(0)
# Out:
# [('resistance', 0.027306180360468505),
#  ('wheat', 0.022536936387512512),
#  ('genes', 0.015326432149689312),
#  ('gene', 0.012973224803286497),
#  ('breeding', 0.010564508038693646),
#  ('genetic', 0.008334712069907636),
#  ('plant', 0.008172686948642576),
#  ('plants', 0.0077816582570526096),
#  ('cultivars', 0.007644248708109173),
#  ('genotypes', 0.007554980210517708)]

# %% [markdown]
# This is the outliers topic

# %%
model.get_topic(2)
# Out:
# [('cows', 0.02477964625381168),
#  ('dairy', 0.02239357360037012),
#  ('milk', 0.019933434338471116),
#  ('cattle', 0.012417915963207972),
#  ('pig', 0.010149702434404785),
#  ('animal', 0.009687357316715972),
#  ('cow', 0.008901690751340622),
#  ('pigs', 0.008148020096708798),
#  ('farm', 0.0076607437896666665),
#  ('feeding', 0.007506514561680994)]

# %% [markdown]
# This one seems to be related to machine learning

# %%
model.get_topic(14)
# Out:
# [('leaf', 0.01709953169884755),
#  ('plant', 0.015461347938547013),
#  ('classification', 0.013272324515412761),
#  ('tree', 0.012575488701553818),
#  ('canopy', 0.012183447987412239),
#  ('leaves', 0.01105078285855785),
#  ('trees', 0.008473905512920798),
#  ('dataset', 0.007336205870198295),
#  ('detection', 0.007298431730194899),
#  ('vegetation', 0.006829647371095687)]

# %% [markdown]
# agriculture

# %% [markdown]
# # **Visualize Topics**

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="a9ce515f-7fe5-4267-aafb-fdd71312a93c" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9ce515f-7fe5-4267-aafb-fdd71312a93c")) {                    Plotly.newPlot(                        "a9ce515f-7fe5-4267-aafb-fdd71312a93c",                        [{"customdata": [[6.272466659545898, 6.000787258148193, 0, "resistance | wheat | genes | gene | breeding", 223], [-3.8496510982513428, 12.154304504394531, 1, "cnn | neural | cnns | training | deep", 221], [3.4617984294891357, -4.337977886199951, 2, "cows | dairy | milk | cattle | pig", 193], [5.726344585418701, 6.740237236022949, 3, "fruit | fruits | detection | apple | tomato", 165], [3.217196464538574, -3.5384678840637207, 4, "wind | model | forecasting | prediction | forecast", 143], [12.902209281921387, 11.895803451538086, 5, "agricultural | technology | technologies | agriculture | farmers", 134], [5.70628547668457, 8.93455982208252, 6, "soil | nitrogen | fertilizer | biochar | soils", 110], [-3.816092014312744, 12.110203742980957, 7, "segmentation | image | images | algorithm | model", 106], [12.83517837524414, 11.833308219909668, 8, "agricultural | production | climate | agriculture | sustainable", 103], [6.512993812561035, 5.391450881958008, 9, "de | la | el | les | des", 89], [12.410420417785645, 11.481595039367676, 10, "urban | cities | agriculture | farms | environmental", 84], [12.74091625213623, 11.714560508728027, 11, "water | irrigation | drought | crop | management", 78], [5.61024284362793, 6.611713886260986, 12, "weed | weeds | crop | aerial | images", 70], [-3.5663111209869385, 11.763958930969238, 13, "classification | hyperspectral | cloud | cnn | clouds", 63], [5.527892589569092, 6.812088966369629, 14, "leaf | plant | classification | tree | canopy", 62], [4.347920894622803, -3.0908217430114746, 15, "iot | smart | internet | farming | agriculture", 61], [-3.5430219173431396, 11.753443717956543, 16, "quantum | neural | tensor | dynamics | energies", 54], [5.795415878295898, 7.168785095214844, 17, "pest | insects | pests | insect | detection", 52], [3.5850229263305664, -4.128288745880127, 18, "detection | rcnn | track | slab | accelerometers", 51], [5.78549861907959, 8.987385749816895, 19, "soil | moisture | digital | algorithms | sensing", 51], [4.273531913757324, -3.1930899620056152, 20, "uav | uavs | aerial | unmanned | uas", 47], [6.15623140335083, 6.056737899780273, 21, "grape | grapevine | vineyard | grapes | vitis", 45], [5.435174942016602, 7.221251010894775, 22, "autonomous | robot | robotics | robots | mowers", 45], [4.789526462554932, -3.618896961212158, 23, "learning | fairness | data | ml | healthcare", 45], [5.842648029327393, 6.886902332305908, 24, "rice | seedling | seedlings | crop | tray", 38], [5.78486967086792, 9.640314102172852, 25, "yang | dengan | adalah | tanaman | antioxidant", 38], [4.091744899749756, -3.583644151687622, 26, "sensor | wsn | wireless | network | iot", 37], [3.653982400894165, -3.741349935531616, 27, "attacks | malicious | attack | intrusion | malware", 34], [-5.423736572265625, -11.507641792297363, 28, "visual | gait | recognition | object | fashion", 32], [5.236338138580322, 6.312648773193359, 29, "agriculturevision | land | segmentation | agriculture | dataset", 29], [5.624655723571777, 7.806182861328125, 30, "seed | plant | soybean | seeds | germination", 27], [6.445205211639404, 5.482730388641357, 31, "stress | drought | root | barley | plants", 27], [-3.365367889404297, 11.271265029907227, 32, "graph | labels | unlabeled | graphbased | labeled", 26], [4.585834503173828, -3.253126859664917, 33, "data | farm | approaches | knowledge | foodkg", 25], [3.4965906143188477, -3.8233582973480225, 34, "fault | detection | diagnosis | bu ...

# %%
new_topics, new_probs = model.reduce_topics(docs, topics, probs, nr_topics=33)

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1   1535
# 1       0    254
# 2       1    243
# 3       2    193
# 4       3    165
# 5       4    143
# 6       5    140
# 7       6    138
# 8       7    134
# 9       8    112
# 10      9    110
# 11     10     89
# 12     11     84
# 13     12     75
# 14     13     74
# 15     14     73
# 16     15     70
# 17     16     68
# 18     17     63
# 19     18     60
# 20     19     59
# 21     20     54
# 22     21     52
# 23     22     52
# 24     23     51
# 25     24     47
# 26     25     45
# 27     26     45
# 28     27     44
# 29     28     39
# 30     29     38
# 31     30     38
# 32     31     37
# 33     32     34

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="b9717ac4-92a8-49b9-b332-dc9339b2f289" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9717ac4-92a8-49b9-b332-dc9339b2f289")) {                    Plotly.newPlot(                        "b9717ac4-92a8-49b9-b332-dc9339b2f289",                        [{"customdata": [[3.058454751968384, 14.687043190002441, 0, "resistance | mildew | wheat | genes | gene", 254], [-6.322033882141113, 4.733765125274658, 1, "cnn | neural | networks | cnns | convolutional", 243], [-7.962092399597168, 4.54042911529541, 2, "cows | dairy | milk | cattle | mastitis", 193], [4.142642498016357, 16.730953216552734, 3, "fruit | detection | fruits | apple | tomato", 165], [-7.7210164070129395, 4.308546543121338, 4, "wind | model | prediction | forecasting | models", 143], [9.838848114013672, -2.811171770095825, 5, "agricultural | production | agriculture | climate | sustainable", 140], [-6.519318103790283, 4.892196178436279, 6, "segmentation | image | images | medical | method", 138], [9.897199630737305, -2.54667067527771, 7, "agricultural | technology | technologies | agriculture | farmers", 134], [9.711874008178711, -2.13055157661438, 8, "water | irrigation | fish | groundwater | drought", 112], [3.306057929992676, 15.343610763549805, 9, "soil | nitrogen | fertilizer | plant | soils", 110], [3.275984764099121, 14.927902221679688, 10, "de | la | el | les | des", 89], [9.715312957763672, -2.9543797969818115, 11, "urban | agriculture | cities | farms | environmental", 84], [7.384338855743408, 5.182246685028076, 12, "iot | smart | internet | agriculture | farming", 75], [3.646233558654785, 16.369178771972656, 13, "leaf | plant | classification | tree | trees", 74], [-7.841602802276611, 4.672205448150635, 14, "fault | detection | rcnn | defect | system", 73], [3.7687792778015137, 16.567495346069336, 15, "weed | weeds | crop | images | field", 70], [-7.050682544708252, 5.051177501678467, 16, "quantum | neural | model | phase | systems", 68], [-6.995434761047363, 5.010225772857666, 17, "classification | hyperspectral | cloud | cnn | clouds", 63], [-7.160278797149658, 5.50507926940918, 18, "graph | sentiment | ssl | labeled | data", 60], [-7.061784267425537, 5.638709545135498, 19, "learning | data | model | audio | models", 59], [2.976308822631836, 14.626232147216797, 20, "stress | seed | drought | plant | barley", 54], [4.309784412384033, 16.315156936645508, 21, "pest | insects | pests | insect | detection", 52], [5.6275177001953125, 17.611434936523438, 22, "corn | flour | edible | oil | wheat", 52], [3.4578850269317627, 15.790289878845215, 23, "soil | data | moisture | mapping | digital", 51], [7.461246967315674, 5.110279560089111, 24, "uav | uavs | aerial | unmanned | uas", 47], [4.075143337249756, 16.013927459716797, 25, "grape | grapevine | mildew | vineyard | leaf", 45], [4.710227012634277, 16.610435485839844, 26, "autonomous | control | robot | robotics | robots", 45], [4.085612773895264, 17.319583892822266, 27, "satellite | agriculture | imagery | sensing | agricultural", 44], [4.22781229019165, 17.425140380859375, 28, "data | machine | ml | agriculture | learning", 39], [5.361538887023926, 17.418575286865234, 29, "rice | crop | seedling | seedlings | farmers", 38], [5.803011894226074, 17.745342254638672, 30, "yang | dengan | adalah | tanaman | menunjukkan", 38], [7.658905029296875, 4.915643692016602, 31, "sensor | wsn | wireless | network | transmission", 37], [-7.155463218688965, 4.8439836502075195, 32, "attacks | detection | malicious | attack | intrusion", 34]], "hovertemplate": "<b>Topic %{customdata[2]}</b><br>Words: %{customdata[3]}<br>Size: %{customdata[4]}", "legendgroup": "", "marker": {"color": "#B0BEC5", "line": {"color": "DarkSlateGrey", "width": 2}, " ...

# %% [markdown]
# Here we reduced the number to 33 to see if our first assumption is relevant.
#
# We can see that the cluster are pretty spaced

# %% [markdown]
# You can see that we can still reduce the number of topics if we want a very llow topic granularity.

# %%
model.find_topics("agriculture")
# Out:
# ([7, 5, 27, 9, 28],
#  [0.8518545761899723,
#   0.8431021045540084,
#   0.675743308534456,
#   0.6502194162663008,
#   0.6107970152718672])

# %%
model.get_topic(7)
# Out:
# [('agricultural', 0.03565437019382535),
#  ('technology', 0.026140116507505806),
#  ('technologies', 0.025191018766316336),
#  ('agriculture', 0.02399745875743113),
#  ('farmers', 0.020352165381229397),
#  ('farming', 0.01690241404833638),
#  ('smart', 0.012369160185100859),
#  ('development', 0.010033620563684323),
#  ('innovation', 0.00941452781672134),
#  ('rural', 0.00829096345981467)]

# %%
model.find_topics("machine learning")
# Out:
# ([19, 28, 1, -1, 26],
#  [0.6228054769533977,
#   0.5893433771438448,
#   0.583040589428113,
#   0.5528516026756964,
#   0.48521100341254775])

# %%
model.get_topic(19)
# Out:
# [('learning', 0.038192074333737634),
#  ('data', 0.01873829285043282),
#  ('model', 0.013674783425643256),
#  ('audio', 0.013612465297208966),
#  ('models', 0.013596429964412085),
#  ('fairness', 0.013477921456525252),
#  ('as', 0.012610033948148306),
#  ('ml', 0.01085955670939449),
#  ('healthcare', 0.00980604712895294),
#  ('supervised', 0.009429501947349846)]

# %% [markdown]
# The result is very interesting because the method of evaluating the proximity between a topic and a word gives probabilities that this topic can be represented by a single word.

# %% [markdown]
# The words that defines topics are way more logic when we create 33 topics.
# Lets see if we ask for 2 topics, we will obtain 2 topics that define agriculture and machine learning.

# %% [markdown]
# # 2 TOPICS

# %%
docs = list(df.loc[:, "abstracts"].values)

# %%
model = BERTopic(language="english",nr_topics=3)

# %%
topics, probs = model.fit_transform(docs)

# %%
model.get_topic_freq()
# Out:
#    Topic  Count
# 0     -1   1540
# 1      0   1212
# 2      1   1100
# 3      2    606

# %%
model.find_topics("agriculture")
# Out:
# ([1, 0, 2, -1],
#  [0.6286732631640763,
#   0.41762277978959006,
#   0.3311495793753889,
#   0.32436338257908837])

# %%
model.get_topic(1)
# Out:
# [('to', 0.06128262780777263),
#  ('for', 0.03765940981166114),
#  ('data', 0.02215323611515929),
#  ('agriculture', 0.02195908129465209),
#  ('agricultural', 0.018556788586467855),
#  ('using', 0.013720183003748965),
#  ('use', 0.012720749746971046),
#  ('learning', 0.012604427999175504),
#  ('water', 0.012456796406484245),
#  ('farming', 0.012391099137114642)]

# %%
model.find_topics("machine learning")
# Out:
# ([2, 1, -1, 0],
#  [0.4688787801961388,
#   0.3184875039725184,
#   0.29089146589564324,
#   0.2871437819998832])

# %%
model.get_topic(2)
# Out:
# [('in', 0.04879732338921885),
#  ('we', 0.034624216579477785),
#  ('that', 0.029920501263070783),
#  ('learning', 0.025694609610814705),
#  ('neural', 0.023517840793407484),
#  ('cnn', 0.021882377052382294),
#  ('segmentation', 0.021457022246107817),
#  ('data', 0.021047214596373723),
#  ('as', 0.020567844773851995),
#  ('model', 0.018847795307258816)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="8e7272c1-c46b-42f0-bc23-85ad25d1c6cd" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e7272c1-c46b-42f0-bc23-85ad25d1c6cd")) {                    Plotly.newPlot(                        "8e7272c1-c46b-42f0-bc23-85ad25d1c6cd",                        [{"customdata": [[9.520346641540527, -8.368924140930176, 0, "of | in | using | we | results", 1212], [10.518506050109863, -7.548096656799316, 1, "to | for | data | agriculture | agricultural", 1100], [9.516563415527344, -6.82291316986084, 2, "in | we | that | learning | neural", 606]], "hovertemplate": "<b>Topic %{customdata[2]}</b><br>Words: %{customdata[3]}<br>Size: %{customdata[4]}", "legendgroup": "", "marker": {"color": "#B0BEC5", "line": {"color": "DarkSlateGrey", "width": 2}, "size": [1212, 1100, 606], "sizemode": "area", "sizeref": 0.7575, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [9.520346641540527, 10.518506050109863, 9.516563415527344], "xaxis": "x", "y": [-8.368924140930176, -7.548096656799316, -6.82291316986084], "yaxis": "y"}],                        {"annotations": [{"showarrow": false, "text": "D1", "x": 8.089078903198242, "y": -7.711869478225708, "yshift": 10}, {"showarrow": false, "text": "D2", "x": 10.092680430412292, "xshift": 10, "y": -5.799476194381714}], "height": 650, "hoverlabel": {"bgcolor": "white", "font": {"family": "Rockwell", "size": 16}}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"line": {"color": "#CFD8DC", "width": 2}, "type": "line", "x0": 10.092680430412292, "x1": 10.092680430412292, "y0": -9.624262762069701, "y1": -5.799476194381714}, {"line": {"color": "#9E9E9E", "width": 2}, "type": "line", "x0": 8.089078903198242, "x1": 12.096281957626342, "y0": -7.711869478225708, "y1": -7.711869478225708}], "sliders": [{"active": 0, "pad": {"t": 50}, "steps": [{"args": [{"marker.color": [["red", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 0", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "red", "#B0BEC5"]]}], "label": "Topic 1", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "red"]]}], "label": "Topic 2", "method": "update"}]}], "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#3 ...

# %% [markdown]
# After a first attempt of creating 2 topics we saw that one topic has been defined by some stopwords. I think that is normal as topwords appears everywhere and we ask the algorithm to overreduce the amount of topic so it end-up to underfit and to generalize.

# %%
import nltk

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
len(docs)
# Out:
# 4458

# %%
stop_words = set(stopwords.words('english')) 

def remove_stopwords(x):
  words = x.split(" ")
  temp = []
  for word in words:
    if word not in stop_words:
      temp.append(word)
  return " ".join(temp)

# %%
df['text_clean'] = df['abstracts'].apply(lambda x: remove_stopwords(x))
df
# Out:
#            doi  ...                                         text_clean
# 0      10.3390  ...  Most people rural areas South Africa SA rely u...
# 1      10.3390  ...  The aim study highlight importance socioeconom...
# 2      10.3390  ...  Urban agriculture gardening provide many healt...
# 3      10.3390  ...  Waste management become pertinent urban region...
# 4      10.3390  ...  Plant growth regulators PGRs described literat...
# ...        ...  ...                                                ...
# 4526  10.2478/  ...  The present paper discusses studies related pr...
# 4527   unknown  ...  El objetivo del trabajo fue desarrollar una me...
# 4528   unknown  ...  Precision agriculture technology transform far...
# 4529  10.1016/  ...  We proposed integrated geospatial service enab...
# 4530  10.5194/  ...  Malaysia currently one biggest global producer...
#
# [4458 rows x 7 columns]

# %%
docs = list(df.loc[:, "text_clean"].values)

# %% [markdown]
# Then we choose to get rid of them and we will see if the result is better

# %%
model = BERTopic(language="english",nr_topics=3)

# %%
topics, probs = model.fit_transform(docs)

# %%
model.get_topic_freq()
# Out:
#    Topic  Count
# 0     -1   3037
# 1      0    607
# 2      1    474
# 3      2    340

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="7c61a0af-3ff8-4c3d-9572-09ab7d96208b" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c61a0af-3ff8-4c3d-9572-09ab7d96208b")) {                    Plotly.newPlot(                        "7c61a0af-3ff8-4c3d-9572-09ab7d96208b",                        [{"customdata": [[0.5517078042030334, -9.523065567016602, 0, "image | segmentation | data | fruit | learning", 607], [-1.0219038724899292, -9.72916316986084, 1, "barley | wheat | mildew | genes | gene", 474], [-0.20949849486351013, -9.976133346557617, 2, "crop | weed | irrigation | plant | field", 340]], "hovertemplate": "<b>Topic %{customdata[2]}</b><br>Words: %{customdata[3]}<br>Size: %{customdata[4]}", "legendgroup": "", "marker": {"color": "#B0BEC5", "line": {"color": "DarkSlateGrey", "width": 2}, "size": [607, 474, 340], "sizemode": "area", "sizeref": 0.379375, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.5517078042030334, -1.0219038724899292, -0.20949849486351013], "xaxis": "x", "y": [-9.523065567016602, -9.72916316986084, -9.976133346557617], "yaxis": "y"}],                        {"annotations": [{"showarrow": false, "text": "D1", "x": -1.1751894533634186, "y": -9.783579540252685, "yshift": 10}, {"showarrow": false, "text": "D2", "x": -0.27036273926496507, "xshift": 10, "y": -8.094605731964112}], "height": 650, "hoverlabel": {"bgcolor": "white", "font": {"family": "Rockwell", "size": 16}}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"line": {"color": "#CFD8DC", "width": 2}, "type": "line", "x0": -0.27036273926496507, "x1": -0.27036273926496507, "y0": -11.47255334854126, "y1": -8.094605731964112}, {"line": {"color": "#9E9E9E", "width": 2}, "type": "line", "x0": -1.1751894533634186, "x1": 0.6344639748334885, "y0": -9.783579540252685, "y1": -9.783579540252685}], "sliders": [{"active": 0, "pad": {"t": 50}, "steps": [{"args": [{"marker.color": [["red", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 0", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "red", "#B0BEC5"]]}], "label": "Topic 1", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "red"]]}], "label": "Topic 2", "method": "update"}]}], "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "# ...

# %% [markdown]
# As we can see removing stopwords is not the best idea as the algorithm yield bad results.

# %% [markdown]
# We still need to create an evaluation pipeline to score the topics created but I can't think of a method

# %% [markdown]
# # Conclusion
#
# As we can see in this notebook our work permits us to extract topic from abstracts. The resuults are pretty good. As the probabilities are high for the two words : ' Agriculture' and 'Machine Learning'.

# %%
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('BERT-Topic-Modelling.ipynb',"/content/drive/MyDrive/Exam/")
# Out:
# --2021-07-09 11:00:45--  https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1864 (1.8K) [text/plain]
# Saving to: ‘colab_pdf.py’
#
# colab_pdf.py        100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2021-07-09 11:00:45 (32.3 MB/s) - ‘colab_pdf.py’ saved [1864/1864]
#
# Mounted at /content/drive/
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Exam/BERT-Topic-Modelling.ipynb to pdf
# /usr/local/lib/python2.7/dist-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) [u'text/html'] is not able to be represented.
#   mimetypes=output.keys())
# [NbConvertApp] Writing 49924 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 44235 bytes to /content/drive/My Drive/BERT-Topic-Modelling.pdf
# 'File ready to be Downloaded and Saved to Drive'
